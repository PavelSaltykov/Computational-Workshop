# %% [markdown]
# Задание 2. Итерационные методы решения СЛАУ (метод простой итерации, метод Зейделя).

# %%
import numpy as np
import pandas as pd
from typing import Callable
from enum import Enum
from numpy import linalg as LA
import math

# %%
class SolvingMethod(Enum):
    SIMPLE_ITERATION = 1,
    SEIDEL = 2


def convert_system(A: np.ndarray, b: np.ndarray) -> tuple[np.ndarray, np.ndarray]:
    inv_diag = LA.inv(np.diag(np.diag(A)))
    return np.identity(A.shape[0]) - (inv_diag @ A), inv_diag @ b


def iterate(H: np.ndarray, g: np.ndarray, stop: Callable[[float, float], bool], limit: int) -> tuple[np.ndarray, int]:    
    if any(LA.eigvals(H) >= 1):
        raise ValueError("Computation does not converge.")
    
    current_x = np.zeros(H.shape[1])
    for step in range(1, limit):
        next_x = H @ current_x + g

        if stop(current_x, next_x):
            return next_x, step
        
        current_x = next_x
    return next_x, step


def solve(A: np.ndarray, b: np.ndarray, accuracy: float, method: SolvingMethod, limit=10000) -> tuple[np.ndarray, int]:
    H, g = convert_system(A, b)
    norm_H = LA.norm(H)

    match method:
        case SolvingMethod.SIMPLE_ITERATION:
            coefficient = norm_H / (1 - norm_H) if norm_H < 1 else 1
        case SolvingMethod.SEIDEL:
            H_l, H_r, E = np.tril(H, -1), np.triu(H), np.identity(H.shape[0])
            H, g = LA.inv(E - H_l) @ H_r, LA.inv(E - H_l) @ g
            coefficient = LA.norm(H_r) / (1 - norm_H) if norm_H < 1 else 1

    stop = lambda current_x, next_x: coefficient * LA.norm(next_x - current_x) <= accuracy
    return iterate(H, g, stop, limit)

# %%
methods = {
    'метод простой итерации': SolvingMethod.SIMPLE_ITERATION,
    'метод Зейделя': SolvingMethod.SEIDEL
}

columns = ['точность', 'метод', 'количество итераций', 'погрешность']

format = {columns[0]: '{:.0e}', 
          columns[3]: '{:.6e}'}

style = [{'selector': 'th', 'props': [('max-width', '100px')]}]

def results_df(matrix: np.ndarray, powers=range(2, 9)) -> pd.DataFrame:
    exact_x = np.ones(matrix.shape[0])
    b = matrix @ exact_x

    data = []
    accuracy = [10 ** -p for p in powers]
    for a in accuracy:
        for m_name, m in methods.items():
            x, steps = solve(matrix, b, a, m)
            data.append([a, m_name, steps, LA.norm(exact_x - x)])
    return pd.DataFrame(data, columns=columns)

# %% [markdown]
# ### Симметричная с диагональным преобладанием разреженная матрица большого порядка

# %%
def generate(size: int, gamma=0.3, max_rand=15) -> np.ndarray:
    limit = size ** (1 + gamma)
    matrix = np.zeros((size, size))

    triu = list(zip(*np.triu_indices_from(matrix, k=1)))
    np.random.shuffle(triu)
    indices_to_fill = triu[:math.floor((limit - size) / 2)]

    for i, j in indices_to_fill:
        matrix[i, j] = (-1) ** np.random.randint(2) * np.random.uniform(-max_rand, 0)
        matrix[j, i] = matrix[i, j]

    diagonal = ((-1) ** np.random.randint(0, 2, size) * 
                np.max([np.sum(abs(matrix), 1), 
                        -np.random.uniform(-max_rand, 0, size)], 0))
    np.fill_diagonal(matrix, diagonal)
    return matrix

# %%
for n in range(200, 501, 100):
    print(f"n = {n}")
    matrix = generate(n)
    display(results_df(matrix).style.format(format).set_table_styles(style).hide())
# Out:
# n = 200
# <style type="text/css">
# #T_f5ba7 th {
#   max-width: 100px;
# }
# </style>
# <table id="T_f5ba7">
#   <thead>
#     <tr>
#       <th id="T_f5ba7_level0_col0" class="col_heading level0 col0" >точность</th>
#       <th id="T_f5ba7_level0_col1" class="col_heading level0 col1" >метод</th>
#       <th id="T_f5ba7_level0_col2" class="col_heading level0 col2" >количество итераций</th>
#       <th id="T_f5ba7_level0_col3" class="col_heading level0 col3" >погрешность</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f5ba7_row0_col0" class="data row0 col0" >1e-02</td>
#       <td id="T_f5ba7_row0_col1" class="data row0 col1" >метод простой итерации</td>
#       <td id="T_f5ba7_row0_col2" class="data row0 col2" >37</td>
#       <td id="T_f5ba7_row0_col3" class="data row0 col3" >1.230641e-02</td>
#     </tr>
#     <tr>
#       <td id="T_f5ba7_row1_col0" class="data row1 col0" >1e-02</td>
#       <td id="T_f5ba7_row1_col1" class="data row1 col1" >метод Зейделя</td>
#       <td id="T_f5ba7_row1_col2" class="data row1 col2" >17</td>
#       <td id="T_f5ba7_row1_col3" class="data row1 col3" >2.855894e-02</td>
#     </tr>
#     <tr>
#       <td id="T_f5ba7_row2_col0" class="data row2 col0" >1e-03</td>
#       <td id="T_f5ba7_row2_col1" class="data row2 col1" >метод простой итерации</td>
#       <td id="T_f5ba7_row2_col2" class="data row2 col2" >55</td>
#       <td id="T_f5ba7_row2_col3" class="data row2 col3" >1.174922e-03</td>
#     </tr>
#     <tr>
#       <td id="T_f5ba7_row3_col0" class="data row3 col0" >1e-03</td>
#       <td id="T_f5ba7_row3_col1" class="data row3 col1" >метод Зейделя</td>
#       <td id="T_f5ba7_row3_col2" class="data row3 col2" >26</td>
#       <td id="T_f5ba7_row3_col3" class="data row3 col3" >2.725345e-03</td>
#     </tr>
#     <tr>
#       <td id="T_f5ba7_row4_col0" class="data row4 col0" >1e-04</td>
#       <td id="T_f5ba7_row4_col1" class="data row4 col1" >метод простой итерации</td>
#       <td id="T_f5ba7_row4_col2" class="data row4 col2" >73</td>
#       <td id="T_f5ba7_row4_col3" class="data row4 col3" >1.121840e-04</td>
#     </tr>
#     <tr>
#       <td id="T_f5ba7_row5_col0" class="data row5 col0" >1e-04</td>
#       <td id="T_f5ba7_row5_col1" class="data row5 col1" >метод Зейделя</td>
#       <td id="T_f5ba7_row5_col2" class="data row5 col2" >35</td>
#       <td id="T_f5ba7_row5_col3" class="data row5 col3" >2.601341e-04</td>
#     </tr>
#     <tr>
#       <td id="T_f5ba7_row6_col0" class="data row6 col0" >1e-05</td>
#       <td id="T_f5ba7_row6_col1" class="data row6 col1" >метод простой итерации</td>
#       <td id="T_f5ba7_row6_col2" class="data row6 col2" >90</td>
#       <td id="T_f5ba7_row6_col3" class="data row6 col3" >1.022575e-05</td>
#     </tr>
#     <tr>
#       <td id="T_f5ba7_row7_col0" class="data row7 col0" >1e-05</td>
#       <td id="T_f5ba7_row7_col1" class="data row7 col1" >метод Зейделя</td>
#       <td id="T_f5ba7_row7_col2" class="data row7 col2" >43</td>
#       <td id="T_f5ba7_row7_col3" class="data row7 col3" >3.223554e-05</td>
#     </tr>
#     <tr>
#       <td id="T_f5ba7_row8_col0" class="data row8 col0" >1e-06</td>
#       <td id="T_f5ba7_row8_col1" class="data row8 col1" >метод простой итерации</td>
#       <td id="T_f5ba7_row8_col2" class="data row8 col2" >107</td>
#       <td id="T_f5ba7_row8_col3" class="data row8 col3" >1.327754e-06</td>
#     </tr>
#     <tr>
#       <td id="T_f5ba7_row9_col0" class="data row9 col0" >1e-06</td>
#       <td id="T_f5ba7_row9_col1" class="data row9 col1" >метод Зейделя</td>
#       <td id="T_f5ba7_row9_col2" class="data row9 col2" >52</td>
#       <td id="T_f5ba7_row9_col3" class="data row9 col3" >3.076914e-06</td>
#     </tr>
#     <tr>
#       <td id="T_f5ba7_row10_col0" class="data row10 col0" >1e-07</td>
#       <td id="T_f5ba7_row10_col1" class="data row10 col1" >метод простой итерации</td>
#       <td id="T_f5ba7_row10_col2" class="data row10 col2" >125</td>
#       <td id="T_f5ba7_row10_col3" class="data row10 col3" >1.267770e-07</td>
#     </tr>
#     <tr>
#       <td id="T_f5ba7_row11_col0" class="data row11 col0" >1e-07</td>
#       <td id="T_f5ba7_row11_col1" class="data row11 col1" >метод Зейделя</td>
#       <td id="T_f5ba7_row11_col2" class="data row11 col2" >61</td>
#       <td id="T_f5ba7_row11_col3" class="data row11 col3" >2.936944e-07</td>
#     </tr>
#     <tr>
#       <td id="T_f5ba7_row12_col0" class="data row12 col0" >1e-08</td>
#       <td id="T_f5ba7_row12_col1" class="data row12 col1" >метод простой итерации</td>
#       <td id="T_f5ba7_row12_col2" class="data row12 col2" >143</td>
#       <td id="T_f5ba7_row12_col3" class="data row12 col3" >1.210496e-08</td>
#     </tr>
#     <tr>
#       <td id="T_f5ba7_row13_col0" class="data row13 col0" >1e-08</td>
#       <td id="T_f5ba7_row13_col1" class="data row13 col1" >метод Зейделя</td>
#       <td id="T_f5ba7_row13_col2" class="data row13 col2" >70</td>
#       <td id="T_f5ba7_row13_col3" class="data row13 col3" >2.803341e-08</td>
#     </tr>
#   </tbody>
# </table>
# n = 300
# <style type="text/css">
# #T_3a36e th {
#   max-width: 100px;
# }
# </style>
# <table id="T_3a36e">
#   <thead>
#     <tr>
#       <th id="T_3a36e_level0_col0" class="col_heading level0 col0" >точность</th>
#       <th id="T_3a36e_level0_col1" class="col_heading level0 col1" >метод</th>
#       <th id="T_3a36e_level0_col2" class="col_heading level0 col2" >количество итераций</th>
#       <th id="T_3a36e_level0_col3" class="col_heading level0 col3" >погрешность</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3a36e_row0_col0" class="data row0 col0" >1e-02</td>
#       <td id="T_3a36e_row0_col1" class="data row0 col1" >метод простой итерации</td>
#       <td id="T_3a36e_row0_col2" class="data row0 col2" >24</td>
#       <td id="T_3a36e_row0_col3" class="data row0 col3" >4.730285e-03</td>
#     </tr>
#     <tr>
#       <td id="T_3a36e_row1_col0" class="data row1 col0" >1e-02</td>
#       <td id="T_3a36e_row1_col1" class="data row1 col1" >метод Зейделя</td>
#       <td id="T_3a36e_row1_col2" class="data row1 col2" >13</td>
#       <td id="T_3a36e_row1_col3" class="data row1 col3" >2.851026e-03</td>
#     </tr>
#     <tr>
#       <td id="T_3a36e_row2_col0" class="data row2 col0" >1e-03</td>
#       <td id="T_3a36e_row2_col1" class="data row2 col1" >метод простой итерации</td>
#       <td id="T_3a36e_row2_col2" class="data row2 col2" >32</td>
#       <td id="T_3a36e_row2_col3" class="data row2 col3" >6.259612e-04</td>
#     </tr>
#     <tr>
#       <td id="T_3a36e_row3_col0" class="data row3 col0" >1e-03</td>
#       <td id="T_3a36e_row3_col1" class="data row3 col1" >метод Зейделя</td>
#       <td id="T_3a36e_row3_col2" class="data row3 col2" >17</td>
#       <td id="T_3a36e_row3_col3" class="data row3 col3" >3.747053e-04</td>
#     </tr>
#     <tr>
#       <td id="T_3a36e_row4_col0" class="data row4 col0" >1e-04</td>
#       <td id="T_3a36e_row4_col1" class="data row4 col1" >метод простой итерации</td>
#       <td id="T_3a36e_row4_col2" class="data row4 col2" >42</td>
#       <td id="T_3a36e_row4_col3" class="data row4 col3" >5.001127e-05</td>
#     </tr>
#     <tr>
#       <td id="T_3a36e_row5_col0" class="data row5 col0" >1e-04</td>
#       <td id="T_3a36e_row5_col1" class="data row5 col1" >метод Зейделя</td>
#       <td id="T_3a36e_row5_col2" class="data row5 col2" >22</td>
#       <td id="T_3a36e_row5_col3" class="data row5 col3" >2.987092e-05</td>
#     </tr>
#     <tr>
#       <td id="T_3a36e_row6_col0" class="data row6 col0" >1e-05</td>
#       <td id="T_3a36e_row6_col1" class="data row6 col1" >метод простой итерации</td>
#       <td id="T_3a36e_row6_col2" class="data row6 col2" >50</td>
#       <td id="T_3a36e_row6_col3" class="data row6 col3" >6.623171e-06</td>
#     </tr>
#     <tr>
#       <td id="T_3a36e_row7_col0" class="data row7 col0" >1e-05</td>
#       <td id="T_3a36e_row7_col1" class="data row7 col1" >метод Зейделя</td>
#       <td id="T_3a36e_row7_col2" class="data row7 col2" >27</td>
#       <td id="T_3a36e_row7_col3" class="data row7 col3" >2.383847e-06</td>
#     </tr>
#     <tr>
#       <td id="T_3a36e_row8_col0" class="data row8 col0" >1e-06</td>
#       <td id="T_3a36e_row8_col1" class="data row8 col1" >метод простой итерации</td>
#       <td id="T_3a36e_row8_col2" class="data row8 col2" >60</td>
#       <td id="T_3a36e_row8_col3" class="data row8 col3" >5.291107e-07</td>
#     </tr>
#     <tr>
#       <td id="T_3a36e_row9_col0" class="data row9 col0" >1e-06</td>
#       <td id="T_3a36e_row9_col1" class="data row9 col1" >метод Зейделя</td>
#       <td id="T_3a36e_row9_col2" class="data row9 col2" >31</td>
#       <td id="T_3a36e_row9_col3" class="data row9 col3" >3.155110e-07</td>
#     </tr>
#     <tr>
#       <td id="T_3a36e_row10_col0" class="data row10 col0" >1e-07</td>
#       <td id="T_3a36e_row10_col1" class="data row10 col1" >метод простой итерации</td>
#       <td id="T_3a36e_row10_col2" class="data row10 col2" >68</td>
#       <td id="T_3a36e_row10_col3" class="data row10 col3" >7.006903e-08</td>
#     </tr>
#     <tr>
#       <td id="T_3a36e_row11_col0" class="data row11 col0" >1e-07</td>
#       <td id="T_3a36e_row11_col1" class="data row11 col1" >метод Зейделя</td>
#       <td id="T_3a36e_row11_col2" class="data row11 col2" >36</td>
#       <td id="T_3a36e_row11_col3" class="data row11 col3" >2.518847e-08</td>
#     </tr>
#     <tr>
#       <td id="T_3a36e_row12_col0" class="data row12 col0" >1e-08</td>
#       <td id="T_3a36e_row12_col1" class="data row12 col1" >метод простой итерации</td>
#       <td id="T_3a36e_row12_col2" class="data row12 col2" >78</td>
#       <td id="T_3a36e_row12_col3" class="data row12 col3" >5.597570e-09</td>
#     </tr>
#     <tr>
#       <td id="T_3a36e_row13_col0" class="data row13 col0" >1e-08</td>
#       <td id="T_3a36e_row13_col1" class="data row13 col1" >метод Зейделя</td>
#       <td id="T_3a36e_row13_col2" class="data row13 col2" >40</td>
#       <td id="T_3a36e_row13_col3" class="data row13 col3" >3.333859e-09</td>
#     </tr>
#   </tbody>
# </table>
# n = 400
# <style type="text/css">
# #T_7d99a th {
#   max-width: 100px;
# }
# </style>
# <table id="T_7d99a">
#   <thead>
#     <tr>
#       <th id="T_7d99a_level0_col0" class="col_heading level0 col0" >точность</th>
#       <th id="T_7d99a_level0_col1" class="col_heading level0 col1" >метод</th>
#       <th id="T_7d99a_level0_col2" class="col_heading level0 col2" >количество итераций</th>
#       <th id="T_7d99a_level0_col3" class="col_heading level0 col3" >погрешность</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7d99a_row0_col0" class="data row0 col0" >1e-02</td>
#       <td id="T_7d99a_row0_col1" class="data row0 col1" >метод простой итерации</td>
#       <td id="T_7d99a_row0_col2" class="data row0 col2" >16</td>
#       <td id="T_7d99a_row0_col3" class="data row0 col3" >1.006996e-02</td>
#     </tr>
#     <tr>
#       <td id="T_7d99a_row1_col0" class="data row1 col0" >1e-02</td>
#       <td id="T_7d99a_row1_col1" class="data row1 col1" >метод Зейделя</td>
#       <td id="T_7d99a_row1_col2" class="data row1 col2" >10</td>
#       <td id="T_7d99a_row1_col3" class="data row1 col3" >6.944557e-03</td>
#     </tr>
#     <tr>
#       <td id="T_7d99a_row2_col0" class="data row2 col0" >1e-03</td>
#       <td id="T_7d99a_row2_col1" class="data row2 col1" >метод простой итерации</td>
#       <td id="T_7d99a_row2_col2" class="data row2 col2" >22</td>
#       <td id="T_7d99a_row2_col3" class="data row2 col3" >1.257253e-03</td>
#     </tr>
#     <tr>
#       <td id="T_7d99a_row3_col0" class="data row3 col0" >1e-03</td>
#       <td id="T_7d99a_row3_col1" class="data row3 col1" >метод Зейделя</td>
#       <td id="T_7d99a_row3_col2" class="data row3 col2" >13</td>
#       <td id="T_7d99a_row3_col3" class="data row3 col3" >9.395929e-04</td>
#     </tr>
#     <tr>
#       <td id="T_7d99a_row4_col0" class="data row4 col0" >1e-04</td>
#       <td id="T_7d99a_row4_col1" class="data row4 col1" >метод простой итерации</td>
#       <td id="T_7d99a_row4_col2" class="data row4 col2" >28</td>
#       <td id="T_7d99a_row4_col3" class="data row4 col3" >1.673988e-04</td>
#     </tr>
#     <tr>
#       <td id="T_7d99a_row5_col0" class="data row5 col0" >1e-04</td>
#       <td id="T_7d99a_row5_col1" class="data row5 col1" >метод Зейделя</td>
#       <td id="T_7d99a_row5_col2" class="data row5 col2" >17</td>
#       <td id="T_7d99a_row5_col3" class="data row5 col3" >6.570853e-05</td>
#     </tr>
#     <tr>
#       <td id="T_7d99a_row6_col0" class="data row6 col0" >1e-05</td>
#       <td id="T_7d99a_row6_col1" class="data row6 col1" >метод простой итерации</td>
#       <td id="T_7d99a_row6_col2" class="data row6 col2" >35</td>
#       <td id="T_7d99a_row6_col3" class="data row6 col3" >1.664524e-05</td>
#     </tr>
#     <tr>
#       <td id="T_7d99a_row7_col0" class="data row7 col0" >1e-05</td>
#       <td id="T_7d99a_row7_col1" class="data row7 col1" >метод Зейделя</td>
#       <td id="T_7d99a_row7_col2" class="data row7 col2" >20</td>
#       <td id="T_7d99a_row7_col3" class="data row7 col3" >8.956322e-06</td>
#     </tr>
#     <tr>
#       <td id="T_7d99a_row8_col0" class="data row8 col0" >1e-06</td>
#       <td id="T_7d99a_row8_col1" class="data row8 col1" >метод простой итерации</td>
#       <td id="T_7d99a_row8_col2" class="data row8 col2" >41</td>
#       <td id="T_7d99a_row8_col3" class="data row8 col3" >2.246335e-06</td>
#     </tr>
#     <tr>
#       <td id="T_7d99a_row9_col0" class="data row9 col0" >1e-06</td>
#       <td id="T_7d99a_row9_col1" class="data row9 col1" >метод Зейделя</td>
#       <td id="T_7d99a_row9_col2" class="data row9 col2" >24</td>
#       <td id="T_7d99a_row9_col3" class="data row9 col3" >6.293817e-07</td>
#     </tr>
#     <tr>
#       <td id="T_7d99a_row10_col0" class="data row10 col0" >1e-07</td>
#       <td id="T_7d99a_row10_col1" class="data row10 col1" >метод простой итерации</td>
#       <td id="T_7d99a_row10_col2" class="data row10 col2" >48</td>
#       <td id="T_7d99a_row10_col3" class="data row10 col3" >2.117670e-07</td>
#     </tr>
#     <tr>
#       <td id="T_7d99a_row11_col0" class="data row11 col0" >1e-07</td>
#       <td id="T_7d99a_row11_col1" class="data row11 col1" >метод Зейделя</td>
#       <td id="T_7d99a_row11_col2" class="data row11 col2" >27</td>
#       <td id="T_7d99a_row11_col3" class="data row11 col3" >8.595026e-08</td>
#     </tr>
#     <tr>
#       <td id="T_7d99a_row12_col0" class="data row12 col0" >1e-08</td>
#       <td id="T_7d99a_row12_col1" class="data row12 col1" >метод простой итерации</td>
#       <td id="T_7d99a_row12_col2" class="data row12 col2" >55</td>
#       <td id="T_7d99a_row12_col3" class="data row12 col3" >2.140278e-08</td>
#     </tr>
#     <tr>
#       <td id="T_7d99a_row13_col0" class="data row13 col0" >1e-08</td>
#       <td id="T_7d99a_row13_col1" class="data row13 col1" >метод Зейделя</td>
#       <td id="T_7d99a_row13_col2" class="data row13 col2" >31</td>
#       <td id="T_7d99a_row13_col3" class="data row13 col3" >6.045406e-09</td>
#     </tr>
#   </tbody>
# </table>
# n = 500
# <style type="text/css">
# #T_84a81 th {
#   max-width: 100px;
# }
# </style>
# <table id="T_84a81">
#   <thead>
#     <tr>
#       <th id="T_84a81_level0_col0" class="col_heading level0 col0" >точность</th>
#       <th id="T_84a81_level0_col1" class="col_heading level0 col1" >метод</th>
#       <th id="T_84a81_level0_col2" class="col_heading level0 col2" >количество итераций</th>
#       <th id="T_84a81_level0_col3" class="col_heading level0 col3" >погрешность</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_84a81_row0_col0" class="data row0 col0" >1e-02</td>
#       <td id="T_84a81_row0_col1" class="data row0 col1" >метод простой итерации</td>
#       <td id="T_84a81_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_84a81_row0_col3" class="data row0 col3" >3.733847e-03</td>
#     </tr>
#     <tr>
#       <td id="T_84a81_row1_col0" class="data row1 col0" >1e-02</td>
#       <td id="T_84a81_row1_col1" class="data row1 col1" >метод Зейделя</td>
#       <td id="T_84a81_row1_col2" class="data row1 col2" >10</td>
#       <td id="T_84a81_row1_col3" class="data row1 col3" >2.195407e-03</td>
#     </tr>
#     <tr>
#       <td id="T_84a81_row2_col0" class="data row2 col0" >1e-03</td>
#       <td id="T_84a81_row2_col1" class="data row2 col1" >метод простой итерации</td>
#       <td id="T_84a81_row2_col2" class="data row2 col2" >23</td>
#       <td id="T_84a81_row2_col3" class="data row2 col3" >5.672043e-04</td>
#     </tr>
#     <tr>
#       <td id="T_84a81_row3_col0" class="data row3 col0" >1e-03</td>
#       <td id="T_84a81_row3_col1" class="data row3 col1" >метод Зейделя</td>
#       <td id="T_84a81_row3_col2" class="data row3 col2" >13</td>
#       <td id="T_84a81_row3_col3" class="data row3 col3" >2.107457e-04</td>
#     </tr>
#     <tr>
#       <td id="T_84a81_row4_col0" class="data row4 col0" >1e-04</td>
#       <td id="T_84a81_row4_col1" class="data row4 col1" >метод простой итерации</td>
#       <td id="T_84a81_row4_col2" class="data row4 col2" >29</td>
#       <td id="T_84a81_row4_col3" class="data row4 col3" >5.608831e-05</td>
#     </tr>
#     <tr>
#       <td id="T_84a81_row5_col0" class="data row5 col0" >1e-04</td>
#       <td id="T_84a81_row5_col1" class="data row5 col1" >метод Зейделя</td>
#       <td id="T_84a81_row5_col2" class="data row5 col2" >16</td>
#       <td id="T_84a81_row5_col3" class="data row5 col3" >2.138723e-05</td>
#     </tr>
#     <tr>
#       <td id="T_84a81_row6_col0" class="data row6 col0" >1e-05</td>
#       <td id="T_84a81_row6_col1" class="data row6 col1" >метод простой итерации</td>
#       <td id="T_84a81_row6_col2" class="data row6 col2" >35</td>
#       <td id="T_84a81_row6_col3" class="data row6 col3" >5.736772e-06</td>
#     </tr>
#     <tr>
#       <td id="T_84a81_row7_col0" class="data row7 col0" >1e-05</td>
#       <td id="T_84a81_row7_col1" class="data row7 col1" >метод Зейделя</td>
#       <td id="T_84a81_row7_col2" class="data row7 col2" >19</td>
#       <td id="T_84a81_row7_col3" class="data row7 col3" >2.259288e-06</td>
#     </tr>
#     <tr>
#       <td id="T_84a81_row8_col0" class="data row8 col0" >1e-06</td>
#       <td id="T_84a81_row8_col1" class="data row8 col1" >метод простой итерации</td>
#       <td id="T_84a81_row8_col2" class="data row8 col2" >41</td>
#       <td id="T_84a81_row8_col3" class="data row8 col3" >6.018499e-07</td>
#     </tr>
#     <tr>
#       <td id="T_84a81_row9_col0" class="data row9 col0" >1e-06</td>
#       <td id="T_84a81_row9_col1" class="data row9 col1" >метод Зейделя</td>
#       <td id="T_84a81_row9_col2" class="data row9 col2" >22</td>
#       <td id="T_84a81_row9_col3" class="data row9 col3" >2.419282e-07</td>
#     </tr>
#     <tr>
#       <td id="T_84a81_row10_col0" class="data row10 col0" >1e-07</td>
#       <td id="T_84a81_row10_col1" class="data row10 col1" >метод простой итерации</td>
#       <td id="T_84a81_row10_col2" class="data row10 col2" >47</td>
#       <td id="T_84a81_row10_col3" class="data row10 col3" >6.411132e-08</td>
#     </tr>
#     <tr>
#       <td id="T_84a81_row11_col0" class="data row11 col0" >1e-07</td>
#       <td id="T_84a81_row11_col1" class="data row11 col1" >метод Зейделя</td>
#       <td id="T_84a81_row11_col2" class="data row11 col2" >25</td>
#       <td id="T_84a81_row11_col3" class="data row11 col3" >2.613224e-08</td>
#     </tr>
#     <tr>
#       <td id="T_84a81_row12_col0" class="data row12 col0" >1e-08</td>
#       <td id="T_84a81_row12_col1" class="data row12 col1" >метод простой итерации</td>
#       <td id="T_84a81_row12_col2" class="data row12 col2" >54</td>
#       <td id="T_84a81_row12_col3" class="data row12 col3" >4.007467e-09</td>
#     </tr>
#     <tr>
#       <td id="T_84a81_row13_col0" class="data row13 col0" >1e-08</td>
#       <td id="T_84a81_row13_col1" class="data row13 col1" >метод Зейделя</td>
#       <td id="T_84a81_row13_col2" class="data row13 col2" >28</td>
#       <td id="T_84a81_row13_col3" class="data row13 col3" >2.826848e-09</td>
#     </tr>
#   </tbody>
# </table>
