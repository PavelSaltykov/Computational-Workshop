# %% [markdown]
# Задание 7. Полная проблема собственных значений (метод Якоби).

# %%
import numpy as np
from enum import Enum
from math import sqrt
from typing import Optional
from numpy import linalg as LA
from scipy.linalg import hilbert
import pandas as pd

# %%
def radius_of_gershgorin_circle(matrix: np.ndarray, i: int) -> float:
    return sum(abs(matrix[i])) - abs(matrix[i, i])


def check_gershgorin_circles(matrix: np.ndarray, eigenvalues: np.ndarray) -> bool:
    size = matrix.shape[0]
    radiuses = [radius_of_gershgorin_circle(matrix, i) for i in range(size)]
    for value in eigenvalues:
        if all(abs(value - matrix[i, i]) > radiuses[i] for i in range(size)):
            return False
    return True

# %%
class SelectionStrategy(Enum):
    ABS_MAXIMUM = 1,
    OPTIMAL_SELECTION = 2


def index_of_nondiag_abs_max(matrix: np.ndarray) -> tuple[int, int]:
    matrix = abs(matrix)
    np.fill_diagonal(matrix, -1)
    return np.unravel_index(np.argmax(matrix), matrix.shape)

# %%
def create_rotation_matrix(matrix: np.ndarray, index: tuple[int, int]) -> np.ndarray:
    result = np.identity(matrix.shape[0])
    i, j = index
    x, y = -2 * matrix[index], matrix[i, i] - matrix[j, j] 

    if y == 0:
        cos_phi, sin_phi = 1 / np.sqrt(2), 1 / np.sqrt(2)
    else:
        cos_phi = sqrt(1 / 2 * (1 + abs(y) / sqrt(x ** 2 + y ** 2)))
        sin_phi = np.sign(x * y) * abs(x) / (2 * cos_phi * sqrt(x ** 2 + y ** 2))
    
    result[i, i], result[j, j] = cos_phi, cos_phi
    result[i, j], result[j, i] = -sin_phi, sin_phi
    return result


def find_eigenvalues(matrix: np.ndarray, accuracy: float, strategy: SelectionStrategy, limit=10000) -> tuple[np.ndarray | None, int]:
    size = matrix.shape[0]
    radiuses = [radius_of_gershgorin_circle(matrix, i) for i in range(size)]
    if all(r < accuracy for r in radiuses):
        return np.diagonal(matrix), 0

    for step in range(1, limit):
        match strategy:
            case SelectionStrategy.ABS_MAXIMUM: 
                i, j = index_of_nondiag_abs_max(matrix)
            case SelectionStrategy.OPTIMAL_SELECTION:
                i = np.argmax(radiuses)
                row = abs(matrix[i])
                row[i] = -1
                j = np.argmax(row)
        
        rotation_matrix = create_rotation_matrix(matrix, (i, j))
        matrix = rotation_matrix @ matrix @ LA.inv(rotation_matrix)

        for index in [i, j]:
            radiuses[index] = radius_of_gershgorin_circle(matrix, index)

        if all(r < accuracy for r in radiuses):
            return np.diagonal(matrix), step
        
    return None, step

# %%
strategies = {
    'максимальный по модулю': SelectionStrategy.ABS_MAXIMUM,
    'оптимальный выбор': SelectionStrategy.OPTIMAL_SELECTION
}

columns = ['точность', 'стратегия', 'количество итераций',
           'ср. погрешность', 'макс. погрешность']

format = {columns[0]: '{:.0e}',
          columns[3]: '{:.6e}',
          columns[4]: '{:.6e}'}

style = [{'selector': 'th', 'props': [('max-width', '100px')]}]


def results_df(matrix: np.ndarray) -> pd.DataFrame:
    exact_values = np.sort(LA.eig(matrix)[0])
    accuracy = [10 ** -p for p in range(2, 11)]
    data = []

    for a in accuracy:
        for s_name, s in strategies.items():
            values, steps = find_eigenvalues(matrix, a, s)
            values = np.sort(values)
            assert check_gershgorin_circles(matrix, values)
            
            errors = [abs(exact_values[i] - values[i]) for i in range(len(values))]
            avg_error = sum(errors) / len(errors)
            max_error = max(errors)
            data.append([a, s_name, steps, avg_error, max_error])

    return pd.DataFrame(data, columns=columns)

# %% [markdown]
# ### Матрица Гильберта

# %%
matrix = hilbert(10)
results_df(matrix).style.format(format).set_table_styles(style).hide()
# Out:
# <style type="text/css">
# #T_75021 th {
#   max-width: 100px;
# }
# </style>
# <table id="T_75021">
#   <thead>
#     <tr>
#       <th id="T_75021_level0_col0" class="col_heading level0 col0" >точность</th>
#       <th id="T_75021_level0_col1" class="col_heading level0 col1" >стратегия</th>
#       <th id="T_75021_level0_col2" class="col_heading level0 col2" >количество итераций</th>
#       <th id="T_75021_level0_col3" class="col_heading level0 col3" >ср. погрешность</th>
#       <th id="T_75021_level0_col4" class="col_heading level0 col4" >макс. погрешность</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_75021_row0_col0" class="data row0 col0" >1e-02</td>
#       <td id="T_75021_row0_col1" class="data row0 col1" >максимальный по модулю</td>
#       <td id="T_75021_row0_col2" class="data row0 col2" >37</td>
#       <td id="T_75021_row0_col3" class="data row0 col3" >3.410909e-04</td>
#       <td id="T_75021_row0_col4" class="data row0 col4" >1.610118e-03</td>
#     </tr>
#     <tr>
#       <td id="T_75021_row1_col0" class="data row1 col0" >1e-02</td>
#       <td id="T_75021_row1_col1" class="data row1 col1" >оптимальный выбор</td>
#       <td id="T_75021_row1_col2" class="data row1 col2" >38</td>
#       <td id="T_75021_row1_col3" class="data row1 col3" >3.384300e-04</td>
#       <td id="T_75021_row1_col4" class="data row1 col4" >1.620751e-03</td>
#     </tr>
#     <tr>
#       <td id="T_75021_row2_col0" class="data row2 col0" >1e-03</td>
#       <td id="T_75021_row2_col1" class="data row2 col1" >максимальный по модулю</td>
#       <td id="T_75021_row2_col2" class="data row2 col2" >55</td>
#       <td id="T_75021_row2_col3" class="data row2 col3" >2.296553e-05</td>
#       <td id="T_75021_row2_col4" class="data row2 col4" >9.305773e-05</td>
#     </tr>
#     <tr>
#       <td id="T_75021_row3_col0" class="data row3 col0" >1e-03</td>
#       <td id="T_75021_row3_col1" class="data row3 col1" >оптимальный выбор</td>
#       <td id="T_75021_row3_col2" class="data row3 col2" >55</td>
#       <td id="T_75021_row3_col3" class="data row3 col3" >2.303134e-05</td>
#       <td id="T_75021_row3_col4" class="data row3 col4" >9.291243e-05</td>
#     </tr>
#     <tr>
#       <td id="T_75021_row4_col0" class="data row4 col0" >1e-04</td>
#       <td id="T_75021_row4_col1" class="data row4 col1" >максимальный по модулю</td>
#       <td id="T_75021_row4_col2" class="data row4 col2" >70</td>
#       <td id="T_75021_row4_col3" class="data row4 col3" >3.616987e-06</td>
#       <td id="T_75021_row4_col4" class="data row4 col4" >1.754276e-05</td>
#     </tr>
#     <tr>
#       <td id="T_75021_row5_col0" class="data row5 col0" >1e-04</td>
#       <td id="T_75021_row5_col1" class="data row5 col1" >оптимальный выбор</td>
#       <td id="T_75021_row5_col2" class="data row5 col2" >74</td>
#       <td id="T_75021_row5_col3" class="data row5 col3" >9.596443e-07</td>
#       <td id="T_75021_row5_col4" class="data row5 col4" >4.026606e-06</td>
#     </tr>
#     <tr>
#       <td id="T_75021_row6_col0" class="data row6 col0" >1e-05</td>
#       <td id="T_75021_row6_col1" class="data row6 col1" >максимальный по модулю</td>
#       <td id="T_75021_row6_col2" class="data row6 col2" >79</td>
#       <td id="T_75021_row6_col3" class="data row6 col3" >5.685204e-07</td>
#       <td id="T_75021_row6_col4" class="data row6 col4" >2.834025e-06</td>
#     </tr>
#     <tr>
#       <td id="T_75021_row7_col0" class="data row7 col0" >1e-05</td>
#       <td id="T_75021_row7_col1" class="data row7 col1" >оптимальный выбор</td>
#       <td id="T_75021_row7_col2" class="data row7 col2" >82</td>
#       <td id="T_75021_row7_col3" class="data row7 col3" >4.967278e-07</td>
#       <td id="T_75021_row7_col4" class="data row7 col4" >2.454160e-06</td>
#     </tr>
#     <tr>
#       <td id="T_75021_row8_col0" class="data row8 col0" >1e-06</td>
#       <td id="T_75021_row8_col1" class="data row8 col1" >максимальный по модулю</td>
#       <td id="T_75021_row8_col2" class="data row8 col2" >99</td>
#       <td id="T_75021_row8_col3" class="data row8 col3" >1.950338e-09</td>
#       <td id="T_75021_row8_col4" class="data row8 col4" >9.293967e-09</td>
#     </tr>
#     <tr>
#       <td id="T_75021_row9_col0" class="data row9 col0" >1e-06</td>
#       <td id="T_75021_row9_col1" class="data row9 col1" >оптимальный выбор</td>
#       <td id="T_75021_row9_col2" class="data row9 col2" >92</td>
#       <td id="T_75021_row9_col3" class="data row9 col3" >2.563747e-09</td>
#       <td id="T_75021_row9_col4" class="data row9 col4" >1.154679e-08</td>
#     </tr>
#     <tr>
#       <td id="T_75021_row10_col0" class="data row10 col0" >1e-07</td>
#       <td id="T_75021_row10_col1" class="data row10 col1" >максимальный по модулю</td>
#       <td id="T_75021_row10_col2" class="data row10 col2" >109</td>
#       <td id="T_75021_row10_col3" class="data row10 col3" >1.872593e-09</td>
#       <td id="T_75021_row10_col4" class="data row10 col4" >9.293967e-09</td>
#     </tr>
#     <tr>
#       <td id="T_75021_row11_col0" class="data row11 col0" >1e-07</td>
#       <td id="T_75021_row11_col1" class="data row11 col1" >оптимальный выбор</td>
#       <td id="T_75021_row11_col2" class="data row11 col2" >107</td>
#       <td id="T_75021_row11_col3" class="data row11 col3" >2.314305e-09</td>
#       <td id="T_75021_row11_col4" class="data row11 col4" >1.155022e-08</td>
#     </tr>
#     <tr>
#       <td id="T_75021_row12_col0" class="data row12 col0" >1e-08</td>
#       <td id="T_75021_row12_col1" class="data row12 col1" >максимальный по модулю</td>
#       <td id="T_75021_row12_col2" class="data row12 col2" >119</td>
#       <td id="T_75021_row12_col3" class="data row12 col3" >1.850528e-10</td>
#       <td id="T_75021_row12_col4" class="data row12 col4" >9.237969e-10</td>
#     </tr>
#     <tr>
#       <td id="T_75021_row13_col0" class="data row13 col0" >1e-08</td>
#       <td id="T_75021_row13_col1" class="data row13 col1" >оптимальный выбор</td>
#       <td id="T_75021_row13_col2" class="data row13 col2" >120</td>
#       <td id="T_75021_row13_col3" class="data row13 col3" >2.699198e-10</td>
#       <td id="T_75021_row13_col4" class="data row13 col4" >1.063829e-09</td>
#     </tr>
#     <tr>
#       <td id="T_75021_row14_col0" class="data row14 col0" >1e-09</td>
#       <td id="T_75021_row14_col1" class="data row14 col1" >максимальный по модулю</td>
#       <td id="T_75021_row14_col2" class="data row14 col2" >130</td>
#       <td id="T_75021_row14_col3" class="data row14 col3" >2.175983e-12</td>
#       <td id="T_75021_row14_col4" class="data row14 col4" >1.087923e-11</td>
#     </tr>
#     <tr>
#       <td id="T_75021_row15_col0" class="data row15 col0" >1e-09</td>
#       <td id="T_75021_row15_col1" class="data row15 col1" >оптимальный выбор</td>
#       <td id="T_75021_row15_col2" class="data row15 col2" >130</td>
#       <td id="T_75021_row15_col3" class="data row15 col3" >2.232148e-12</td>
#       <td id="T_75021_row15_col4" class="data row15 col4" >1.113189e-11</td>
#     </tr>
#     <tr>
#       <td id="T_75021_row16_col0" class="data row16 col0" >1e-10</td>
#       <td id="T_75021_row16_col1" class="data row16 col1" >максимальный по модулю</td>
#       <td id="T_75021_row16_col2" class="data row16 col2" >137</td>
#       <td id="T_75021_row16_col3" class="data row16 col3" >2.175987e-12</td>
#       <td id="T_75021_row16_col4" class="data row16 col4" >1.087923e-11</td>
#     </tr>
#     <tr>
#       <td id="T_75021_row17_col0" class="data row17 col0" >1e-10</td>
#       <td id="T_75021_row17_col1" class="data row17 col1" >оптимальный выбор</td>
#       <td id="T_75021_row17_col2" class="data row17 col2" >141</td>
#       <td id="T_75021_row17_col3" class="data row17 col3" >2.217042e-12</td>
#       <td id="T_75021_row17_col4" class="data row17 col4" >1.107874e-11</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Трехдиагональная матрица

# %%
size = 10
matrix = np.identity(size) + -3 * np.eye(size, k=-1) + -3 * np.eye(size, k=1)
results_df(matrix).style.format(format).set_table_styles(style).hide()
# Out:
# <style type="text/css">
# #T_a2e00 th {
#   max-width: 100px;
# }
# </style>
# <table id="T_a2e00">
#   <thead>
#     <tr>
#       <th id="T_a2e00_level0_col0" class="col_heading level0 col0" >точность</th>
#       <th id="T_a2e00_level0_col1" class="col_heading level0 col1" >стратегия</th>
#       <th id="T_a2e00_level0_col2" class="col_heading level0 col2" >количество итераций</th>
#       <th id="T_a2e00_level0_col3" class="col_heading level0 col3" >ср. погрешность</th>
#       <th id="T_a2e00_level0_col4" class="col_heading level0 col4" >макс. погрешность</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a2e00_row0_col0" class="data row0 col0" >1e-02</td>
#       <td id="T_a2e00_row0_col1" class="data row0 col1" >максимальный по модулю</td>
#       <td id="T_a2e00_row0_col2" class="data row0 col2" >96</td>
#       <td id="T_a2e00_row0_col3" class="data row0 col3" >1.075056e-06</td>
#       <td id="T_a2e00_row0_col4" class="data row0 col4" >2.160398e-06</td>
#     </tr>
#     <tr>
#       <td id="T_a2e00_row1_col0" class="data row1 col0" >1e-02</td>
#       <td id="T_a2e00_row1_col1" class="data row1 col1" >оптимальный выбор</td>
#       <td id="T_a2e00_row1_col2" class="data row1 col2" >98</td>
#       <td id="T_a2e00_row1_col3" class="data row1 col3" >2.857695e-06</td>
#       <td id="T_a2e00_row1_col4" class="data row1 col4" >6.257568e-06</td>
#     </tr>
#     <tr>
#       <td id="T_a2e00_row2_col0" class="data row2 col0" >1e-03</td>
#       <td id="T_a2e00_row2_col1" class="data row2 col1" >максимальный по модулю</td>
#       <td id="T_a2e00_row2_col2" class="data row2 col2" >111</td>
#       <td id="T_a2e00_row2_col3" class="data row2 col3" >3.804082e-08</td>
#       <td id="T_a2e00_row2_col4" class="data row2 col4" >9.910516e-08</td>
#     </tr>
#     <tr>
#       <td id="T_a2e00_row3_col0" class="data row3 col0" >1e-03</td>
#       <td id="T_a2e00_row3_col1" class="data row3 col1" >оптимальный выбор</td>
#       <td id="T_a2e00_row3_col2" class="data row3 col2" >113</td>
#       <td id="T_a2e00_row3_col3" class="data row3 col3" >4.198463e-08</td>
#       <td id="T_a2e00_row3_col4" class="data row3 col4" >8.041062e-08</td>
#     </tr>
#     <tr>
#       <td id="T_a2e00_row4_col0" class="data row4 col0" >1e-04</td>
#       <td id="T_a2e00_row4_col1" class="data row4 col1" >максимальный по модулю</td>
#       <td id="T_a2e00_row4_col2" class="data row4 col2" >119</td>
#       <td id="T_a2e00_row4_col3" class="data row4 col3" >1.461639e-10</td>
#       <td id="T_a2e00_row4_col4" class="data row4 col4" >3.112435e-10</td>
#     </tr>
#     <tr>
#       <td id="T_a2e00_row5_col0" class="data row5 col0" >1e-04</td>
#       <td id="T_a2e00_row5_col1" class="data row5 col1" >оптимальный выбор</td>
#       <td id="T_a2e00_row5_col2" class="data row5 col2" >127</td>
#       <td id="T_a2e00_row5_col3" class="data row5 col3" >1.299372e-10</td>
#       <td id="T_a2e00_row5_col4" class="data row5 col4" >3.337277e-10</td>
#     </tr>
#     <tr>
#       <td id="T_a2e00_row6_col0" class="data row6 col0" >1e-05</td>
#       <td id="T_a2e00_row6_col1" class="data row6 col1" >максимальный по модулю</td>
#       <td id="T_a2e00_row6_col2" class="data row6 col2" >128</td>
#       <td id="T_a2e00_row6_col3" class="data row6 col3" >3.501571e-12</td>
#       <td id="T_a2e00_row6_col4" class="data row6 col4" >1.041922e-11</td>
#     </tr>
#     <tr>
#       <td id="T_a2e00_row7_col0" class="data row7 col0" >1e-05</td>
#       <td id="T_a2e00_row7_col1" class="data row7 col1" >оптимальный выбор</td>
#       <td id="T_a2e00_row7_col2" class="data row7 col2" >132</td>
#       <td id="T_a2e00_row7_col3" class="data row7 col3" >6.858575e-12</td>
#       <td id="T_a2e00_row7_col4" class="data row7 col4" >2.568967e-11</td>
#     </tr>
#     <tr>
#       <td id="T_a2e00_row8_col0" class="data row8 col0" >1e-06</td>
#       <td id="T_a2e00_row8_col1" class="data row8 col1" >максимальный по модулю</td>
#       <td id="T_a2e00_row8_col2" class="data row8 col2" >138</td>
#       <td id="T_a2e00_row8_col3" class="data row8 col3" >2.956801e-14</td>
#       <td id="T_a2e00_row8_col4" class="data row8 col4" >7.460699e-14</td>
#     </tr>
#     <tr>
#       <td id="T_a2e00_row9_col0" class="data row9 col0" >1e-06</td>
#       <td id="T_a2e00_row9_col1" class="data row9 col1" >оптимальный выбор</td>
#       <td id="T_a2e00_row9_col2" class="data row9 col2" >142</td>
#       <td id="T_a2e00_row9_col3" class="data row9 col3" >9.631185e-15</td>
#       <td id="T_a2e00_row9_col4" class="data row9 col4" >2.575717e-14</td>
#     </tr>
#     <tr>
#       <td id="T_a2e00_row10_col0" class="data row10 col0" >1e-07</td>
#       <td id="T_a2e00_row10_col1" class="data row10 col1" >максимальный по модулю</td>
#       <td id="T_a2e00_row10_col2" class="data row10 col2" >143</td>
#       <td id="T_a2e00_row10_col3" class="data row10 col3" >2.736700e-15</td>
#       <td id="T_a2e00_row10_col4" class="data row10 col4" >9.769963e-15</td>
#     </tr>
#     <tr>
#       <td id="T_a2e00_row11_col0" class="data row11 col0" >1e-07</td>
#       <td id="T_a2e00_row11_col1" class="data row11 col1" >оптимальный выбор</td>
#       <td id="T_a2e00_row11_col2" class="data row11 col2" >148</td>
#       <td id="T_a2e00_row11_col3" class="data row11 col3" >2.833844e-15</td>
#       <td id="T_a2e00_row11_col4" class="data row11 col4" >7.105427e-15</td>
#     </tr>
#     <tr>
#       <td id="T_a2e00_row12_col0" class="data row12 col0" >1e-08</td>
#       <td id="T_a2e00_row12_col1" class="data row12 col1" >максимальный по модулю</td>
#       <td id="T_a2e00_row12_col2" class="data row12 col2" >149</td>
#       <td id="T_a2e00_row12_col3" class="data row12 col3" >2.781109e-15</td>
#       <td id="T_a2e00_row12_col4" class="data row12 col4" >9.769963e-15</td>
#     </tr>
#     <tr>
#       <td id="T_a2e00_row13_col0" class="data row13 col0" >1e-08</td>
#       <td id="T_a2e00_row13_col1" class="data row13 col1" >оптимальный выбор</td>
#       <td id="T_a2e00_row13_col2" class="data row13 col2" >156</td>
#       <td id="T_a2e00_row13_col3" class="data row13 col3" >3.136380e-15</td>
#       <td id="T_a2e00_row13_col4" class="data row13 col4" >7.105427e-15</td>
#     </tr>
#     <tr>
#       <td id="T_a2e00_row14_col0" class="data row14 col0" >1e-09</td>
#       <td id="T_a2e00_row14_col1" class="data row14 col1" >максимальный по модулю</td>
#       <td id="T_a2e00_row14_col2" class="data row14 col2" >153</td>
#       <td id="T_a2e00_row14_col3" class="data row14 col3" >2.781109e-15</td>
#       <td id="T_a2e00_row14_col4" class="data row14 col4" >9.769963e-15</td>
#     </tr>
#     <tr>
#       <td id="T_a2e00_row15_col0" class="data row15 col0" >1e-09</td>
#       <td id="T_a2e00_row15_col1" class="data row15 col1" >оптимальный выбор</td>
#       <td id="T_a2e00_row15_col2" class="data row15 col2" >161</td>
#       <td id="T_a2e00_row15_col3" class="data row15 col3" >3.136380e-15</td>
#       <td id="T_a2e00_row15_col4" class="data row15 col4" >7.105427e-15</td>
#     </tr>
#     <tr>
#       <td id="T_a2e00_row16_col0" class="data row16 col0" >1e-10</td>
#       <td id="T_a2e00_row16_col1" class="data row16 col1" >максимальный по модулю</td>
#       <td id="T_a2e00_row16_col2" class="data row16 col2" >159</td>
#       <td id="T_a2e00_row16_col3" class="data row16 col3" >2.781109e-15</td>
#       <td id="T_a2e00_row16_col4" class="data row16 col4" >9.769963e-15</td>
#     </tr>
#     <tr>
#       <td id="T_a2e00_row17_col0" class="data row17 col0" >1e-10</td>
#       <td id="T_a2e00_row17_col1" class="data row17 col1" >оптимальный выбор</td>
#       <td id="T_a2e00_row17_col2" class="data row17 col2" >164</td>
#       <td id="T_a2e00_row17_col3" class="data row17 col3" >3.136380e-15</td>
#       <td id="T_a2e00_row17_col4" class="data row17 col4" >7.105427e-15</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Матрица с диагональным преобладанием

# %%
size = 5
matrix = 10 * np.identity(size) + -2 * np.eye(size, k=1) + 2 * np.eye(size, k=2) + 3 * np.eye(size, k=4)
matrix += np.triu(matrix, k=1).T
results_df(matrix).style.format(format).set_table_styles(style).hide()
# Out:
# <style type="text/css">
# #T_e274d th {
#   max-width: 100px;
# }
# </style>
# <table id="T_e274d">
#   <thead>
#     <tr>
#       <th id="T_e274d_level0_col0" class="col_heading level0 col0" >точность</th>
#       <th id="T_e274d_level0_col1" class="col_heading level0 col1" >стратегия</th>
#       <th id="T_e274d_level0_col2" class="col_heading level0 col2" >количество итераций</th>
#       <th id="T_e274d_level0_col3" class="col_heading level0 col3" >ср. погрешность</th>
#       <th id="T_e274d_level0_col4" class="col_heading level0 col4" >макс. погрешность</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e274d_row0_col0" class="data row0 col0" >1e-02</td>
#       <td id="T_e274d_row0_col1" class="data row0 col1" >максимальный по модулю</td>
#       <td id="T_e274d_row0_col2" class="data row0 col2" >19</td>
#       <td id="T_e274d_row0_col3" class="data row0 col3" >1.371358e-05</td>
#       <td id="T_e274d_row0_col4" class="data row0 col4" >2.991529e-05</td>
#     </tr>
#     <tr>
#       <td id="T_e274d_row1_col0" class="data row1 col0" >1e-02</td>
#       <td id="T_e274d_row1_col1" class="data row1 col1" >оптимальный выбор</td>
#       <td id="T_e274d_row1_col2" class="data row1 col2" >20</td>
#       <td id="T_e274d_row1_col3" class="data row1 col3" >1.360823e-05</td>
#       <td id="T_e274d_row1_col4" class="data row1 col4" >3.401904e-05</td>
#     </tr>
#     <tr>
#       <td id="T_e274d_row2_col0" class="data row2 col0" >1e-03</td>
#       <td id="T_e274d_row2_col1" class="data row2 col1" >максимальный по модулю</td>
#       <td id="T_e274d_row2_col2" class="data row2 col2" >22</td>
#       <td id="T_e274d_row2_col3" class="data row2 col3" >6.052973e-09</td>
#       <td id="T_e274d_row2_col4" class="data row2 col4" >1.492072e-08</td>
#     </tr>
#     <tr>
#       <td id="T_e274d_row3_col0" class="data row3 col0" >1e-03</td>
#       <td id="T_e274d_row3_col1" class="data row3 col1" >оптимальный выбор</td>
#       <td id="T_e274d_row3_col2" class="data row3 col2" >23</td>
#       <td id="T_e274d_row3_col3" class="data row3 col3" >2.976416e-08</td>
#       <td id="T_e274d_row3_col4" class="data row3 col4" >7.287479e-08</td>
#     </tr>
#     <tr>
#       <td id="T_e274d_row4_col0" class="data row4 col0" >1e-04</td>
#       <td id="T_e274d_row4_col1" class="data row4 col1" >максимальный по модулю</td>
#       <td id="T_e274d_row4_col2" class="data row4 col2" >24</td>
#       <td id="T_e274d_row4_col3" class="data row4 col3" >7.759159e-10</td>
#       <td id="T_e274d_row4_col4" class="data row4 col4" >1.728073e-09</td>
#     </tr>
#     <tr>
#       <td id="T_e274d_row5_col0" class="data row5 col0" >1e-04</td>
#       <td id="T_e274d_row5_col1" class="data row5 col1" >оптимальный выбор</td>
#       <td id="T_e274d_row5_col2" class="data row5 col2" >24</td>
#       <td id="T_e274d_row5_col3" class="data row5 col3" >3.088235e-09</td>
#       <td id="T_e274d_row5_col4" class="data row5 col4" >6.184996e-09</td>
#     </tr>
#     <tr>
#       <td id="T_e274d_row6_col0" class="data row6 col0" >1e-05</td>
#       <td id="T_e274d_row6_col1" class="data row6 col1" >максимальный по модулю</td>
#       <td id="T_e274d_row6_col2" class="data row6 col2" >27</td>
#       <td id="T_e274d_row6_col3" class="data row6 col3" >3.085532e-13</td>
#       <td id="T_e274d_row6_col4" class="data row6 col4" >7.691625e-13</td>
#     </tr>
#     <tr>
#       <td id="T_e274d_row7_col0" class="data row7 col0" >1e-05</td>
#       <td id="T_e274d_row7_col1" class="data row7 col1" >оптимальный выбор</td>
#       <td id="T_e274d_row7_col2" class="data row7 col2" >27</td>
#       <td id="T_e274d_row7_col3" class="data row7 col3" >1.918465e-14</td>
#       <td id="T_e274d_row7_col4" class="data row7 col4" >4.085621e-14</td>
#     </tr>
#     <tr>
#       <td id="T_e274d_row8_col0" class="data row8 col0" >1e-06</td>
#       <td id="T_e274d_row8_col1" class="data row8 col1" >максимальный по модулю</td>
#       <td id="T_e274d_row8_col2" class="data row8 col2" >28</td>
#       <td id="T_e274d_row8_col3" class="data row8 col3" >2.842171e-15</td>
#       <td id="T_e274d_row8_col4" class="data row8 col4" >4.440892e-15</td>
#     </tr>
#     <tr>
#       <td id="T_e274d_row9_col0" class="data row9 col0" >1e-06</td>
#       <td id="T_e274d_row9_col1" class="data row9 col1" >оптимальный выбор</td>
#       <td id="T_e274d_row9_col2" class="data row9 col2" >27</td>
#       <td id="T_e274d_row9_col3" class="data row9 col3" >1.918465e-14</td>
#       <td id="T_e274d_row9_col4" class="data row9 col4" >4.085621e-14</td>
#     </tr>
#     <tr>
#       <td id="T_e274d_row10_col0" class="data row10 col0" >1e-07</td>
#       <td id="T_e274d_row10_col1" class="data row10 col1" >максимальный по модулю</td>
#       <td id="T_e274d_row10_col2" class="data row10 col2" >29</td>
#       <td id="T_e274d_row10_col3" class="data row10 col3" >1.776357e-15</td>
#       <td id="T_e274d_row10_col4" class="data row10 col4" >3.552714e-15</td>
#     </tr>
#     <tr>
#       <td id="T_e274d_row11_col0" class="data row11 col0" >1e-07</td>
#       <td id="T_e274d_row11_col1" class="data row11 col1" >оптимальный выбор</td>
#       <td id="T_e274d_row11_col2" class="data row11 col2" >29</td>
#       <td id="T_e274d_row11_col3" class="data row11 col3" >2.486900e-15</td>
#       <td id="T_e274d_row11_col4" class="data row11 col4" >1.065814e-14</td>
#     </tr>
#     <tr>
#       <td id="T_e274d_row12_col0" class="data row12 col0" >1e-08</td>
#       <td id="T_e274d_row12_col1" class="data row12 col1" >максимальный по модулю</td>
#       <td id="T_e274d_row12_col2" class="data row12 col2" >29</td>
#       <td id="T_e274d_row12_col3" class="data row12 col3" >1.776357e-15</td>
#       <td id="T_e274d_row12_col4" class="data row12 col4" >3.552714e-15</td>
#     </tr>
#     <tr>
#       <td id="T_e274d_row13_col0" class="data row13 col0" >1e-08</td>
#       <td id="T_e274d_row13_col1" class="data row13 col1" >оптимальный выбор</td>
#       <td id="T_e274d_row13_col2" class="data row13 col2" >31</td>
#       <td id="T_e274d_row13_col3" class="data row13 col3" >2.664535e-15</td>
#       <td id="T_e274d_row13_col4" class="data row13 col4" >1.065814e-14</td>
#     </tr>
#     <tr>
#       <td id="T_e274d_row14_col0" class="data row14 col0" >1e-09</td>
#       <td id="T_e274d_row14_col1" class="data row14 col1" >максимальный по модулю</td>
#       <td id="T_e274d_row14_col2" class="data row14 col2" >31</td>
#       <td id="T_e274d_row14_col3" class="data row14 col3" >1.776357e-15</td>
#       <td id="T_e274d_row14_col4" class="data row14 col4" >3.552714e-15</td>
#     </tr>
#     <tr>
#       <td id="T_e274d_row15_col0" class="data row15 col0" >1e-09</td>
#       <td id="T_e274d_row15_col1" class="data row15 col1" >оптимальный выбор</td>
#       <td id="T_e274d_row15_col2" class="data row15 col2" >31</td>
#       <td id="T_e274d_row15_col3" class="data row15 col3" >2.664535e-15</td>
#       <td id="T_e274d_row15_col4" class="data row15 col4" >1.065814e-14</td>
#     </tr>
#     <tr>
#       <td id="T_e274d_row16_col0" class="data row16 col0" >1e-10</td>
#       <td id="T_e274d_row16_col1" class="data row16 col1" >максимальный по модулю</td>
#       <td id="T_e274d_row16_col2" class="data row16 col2" >32</td>
#       <td id="T_e274d_row16_col3" class="data row16 col3" >1.776357e-15</td>
#       <td id="T_e274d_row16_col4" class="data row16 col4" >3.552714e-15</td>
#     </tr>
#     <tr>
#       <td id="T_e274d_row17_col0" class="data row17 col0" >1e-10</td>
#       <td id="T_e274d_row17_col1" class="data row17 col1" >оптимальный выбор</td>
#       <td id="T_e274d_row17_col2" class="data row17 col2" >32</td>
#       <td id="T_e274d_row17_col3" class="data row17 col3" >2.664535e-15</td>
#       <td id="T_e274d_row17_col4" class="data row17 col4" >1.065814e-14</td>
#     </tr>
#   </tbody>
# </table>
